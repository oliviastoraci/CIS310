# %% [markdown]
# # Olivia Storaci
# ## Week 16: 04/03/2022
# ### Python - Data Cleaning & Visualization - Stock Market Project Amazon

# %%
# The Normal Imports:
import numpy as np
from numpy.random import randn
import pandas as pd

# These are the plotting modules & Libraries we will use:
import matplotlib as mpl
import matplotlib.pyplot as plt

# Command so plots appears in IPython Notebook:
# %matplotlib inline

# %%
# Upload dataset from a CSV File. Read data from thise file in the wk folder already
data = pd.read_csv('AMZN.csv')

# %%
# Learn about the data. What information can we get from it?
# See the first ten records. Without a number it will give you 5. Spceify with a number
data.head()
# Out:
#        Date Source        Open        High         Low       Close  \
# 0  1/3/2012  yahoo  175.889999  179.479996  175.550003  179.029999
# 1  1/4/2012  yahoo  179.210007  180.500000  176.070007  177.509995
# 2  1/5/2012  yahoo  175.940002  178.250000  174.050003  177.610001
# 3  1/6/2012  yahoo  178.070007  184.649994  177.500000  182.610001
# 4  1/9/2012  yahoo  182.759995  184.369995  177.000000  178.559998
#
#     Adj Close   Volume   Stock
# 0  179.029999  5110800  amazon
# 1  177.509995  4205200  amazon
# 2  177.610001  3809100  amazon
# 3  182.610001  7008400  amazon
# 4  178.559998  5056900  amazon

# %%
data.head(20)
# Out:
#          Date Source        Open        High         Low       Close  \
# 0    1/3/2012  yahoo  175.889999  179.479996  175.550003  179.029999
# 1    1/4/2012  yahoo  179.210007  180.500000  176.070007  177.509995
# 2    1/5/2012  yahoo  175.940002  178.250000  174.050003  177.610001
# 3    1/6/2012  yahoo  178.070007  184.649994  177.500000  182.610001
# 4    1/9/2012  yahoo  182.759995  184.369995  177.000000  178.559998
# 5   1/10/2012  yahoo  181.100006  182.399994  177.100006  179.339996
# 6   1/11/2012  yahoo  179.639999  180.770004  178.190002  178.899994
# 7   1/12/2012  yahoo  179.419998  179.490005  175.750000  175.929993
# 8   1/13/2012  yahoo  175.809998  178.800003  173.500000  178.419998
# 9   1/17/2012  yahoo  180.149994  183.300003  178.509995  181.660004
# 10  1/18/2012  yahoo  181.940002  190.250000  181.119995  189.440002
# 11  1/19/2012  yahoo  190.880005  195.940002  190.360001  194.449997
# 12  1/20/2012  yahoo  190.710007  192.899994  189.039993  190.929993
# ...

# %%
# lAST 5 FILES IN THE INFO. So fast - PANDAS
data.tail()
# Out:
#             Date Source         Open         High          Low        Close  \
# 2237  11/20/2020  yahoo  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  yahoo  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  yahoo  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  yahoo  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  yahoo  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume   Stock
# 2237  3099.399902  3374400  amazon
# 2238  3098.389893  4708900  amazon
# 2239  3118.060059  3602100  amazon
# 2240  3185.070068  3790400  amazon
# 2241  3195.340088  2392900  amazon

# %%
data.tail(10)
# Out:
#             Date Source         Open         High          Low        Close  \
# 2232  11/13/2020  yahoo  3122.000000  3141.719971  3085.389893  3128.810059
# 2233  11/16/2020  yahoo  3093.199951  3142.699951  3072.689941  3131.060059
# 2234  11/17/2020  yahoo  3183.540039  3189.250000  3135.260010  3135.659912
# 2235  11/18/2020  yahoo  3134.000000  3140.000000  3105.100098  3105.459961
# 2236  11/19/2020  yahoo  3105.310059  3125.000000  3080.919922  3117.020020
# 2237  11/20/2020  yahoo  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  yahoo  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  yahoo  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  yahoo  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  yahoo  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume   Stock
# 2232  3128.810059  3756200  amazon
# 2233  3131.060059  3808700  amazon
# ...

# %%
# Describe. Info about the data
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2241.000000  2240.000000  2242.000000  2239.000000  2241.000000
# mean    991.401419  1002.190218   979.221717   991.895355   991.190696
# std     802.269032   811.968123   790.843600   801.664757   801.654109
# min     173.809998   178.250000   172.000000   175.929993   175.929993
# 25%     320.359985   323.687500   315.807487   321.385010   320.510010
# 50%     717.380005   723.394989   712.629975   719.299988   719.070007
# 75%    1660.000000  1679.964966  1633.707459  1661.830017  1660.510010
# max    3547.000000  3552.250000  3486.689941  3531.449951  3531.449951
#
#              Volume
# count  2.242000e+03
# mean   4.118187e+06
# std    2.278888e+06
# min    0.000000e+00
# 25%    2.688550e+06
# 50%    3.528700e+06
# 75%    4.839800e+06
# max    2.385610e+07

# %%
# How many entries, columns, rows, etc.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2242 entries, 0 to 2241
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2242 non-null   object
#  1   Source     2242 non-null   object
#  2   Open       2241 non-null   float64
#  3   High       2240 non-null   float64
#  4   Low        2242 non-null   float64
#  5   Close      2239 non-null   float64
#  6   Adj Close  2241 non-null   float64
#  7   Volume     2242 non-null   int64
#  8   Stock      2242 non-null   object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 157.8+ KB

# %%
data.columns
# Out:
# Index(['Date', 'Source', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Stock'],
#       dtype='object')

# %%
# Elements you have in the list. 9 columns
len(data.columns)
# Out:
# 9

# %%
# First five and last five indexes
data['Adj Close']
# Out:
# 0        179.029999
# 1        177.509995
# 2        177.610001
# 3        182.610001
# 4        178.559998
#            ...
# 2237    3099.399902
# 2238    3098.389893
# 2239    3118.060059
# 2240    3185.070068
# 2241    3195.340088
# Name: Adj Close, Length: 2242, dtype: float64

# %%
data['Adj Close'].plot(legend=True, figsize=(10,4))

# %%
# COunt the number of numerical and non-numerical variables (columns)
# N tells us number of columns
from pandas.api.types import is_numeric_dtype

n=0

for c in data.columns:
    if is_numeric_dtype(data[c]):
        n+=1

print('Numerical Variables: ', n, 'Non-Numerical Variables: ', len(data.columns)-n)
# Out:
# Numerical Variables:  6 Non-Numerical Variables:  3

# %%
# Data Cleaning - Preparing Data for Analytics
data.isnull()
# Out:
#        Date  Source   Open   High    Low  Close  Adj Close  Volume  Stock
# 0     False   False  False  False  False  False      False   False  False
# 1     False   False  False  False  False  False      False   False  False
# 2     False   False  False  False  False  False      False   False  False
# 3     False   False  False  False  False  False      False   False  False
# 4     False   False  False  False  False  False      False   False  False
# ...     ...     ...    ...    ...    ...    ...        ...     ...    ...
# 2237  False   False  False  False  False  False      False   False  False
# 2238  False   False  False  False  False  False      False   False  False
# 2239  False   False  False  False  False  False      False   False  False
# 2240  False   False  False  False  False  False      False   False  False
# 2241  False   False  False  False  False  False      False   False  False
#
# [2242 rows x 9 columns]

# %%
# Identify the sum of the null values in the data set. Num missing vals in each row
data.isnull().sum()
# Out:
# Date         0
# Source       0
# Open         1
# High         2
# Low          0
# Close        3
# Adj Close    1
# Volume       0
# Stock        0
# dtype: int64

# %%
# Handle missing Data
# See the data being dropped - 
data.dropna()
# Out:
#             Date Source         Open         High          Low        Close  \
# 0       1/3/2012  yahoo   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012  yahoo   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012  yahoo   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012  yahoo   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012  yahoo   182.759995   184.369995   177.000000   178.559998
# ...          ...    ...          ...          ...          ...          ...
# 2237  11/20/2020  yahoo  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  yahoo  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  yahoo  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  yahoo  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  yahoo  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume   Stock
# ...

# %%
# Best way to drop data and change the data. Change the data itself
data.dropna(inplace=True)

# %%
# Now see the permanent data without any null values
data.isnull().sum()
# Out:
# Date         0
# Source       0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# Stock        0
# dtype: int64

# %%
#Clean Abnormal Values. histogram specification on plot. 
data['Volume'].plot(kind='hist', color='y',bins=50)

# %%
# Change the bins - you need more
data['Volume'].plot(kind='hist', color='indianred',bins=200)

# %%
# WHATS THE MIN IN THE DATA
data['Volume'].min()
# Out:
# 0

# %%
# WHATS THE MAX IN THE DATA
data['Volume'].max()
# Out:
# 23856100

# %%
# How small - first 20
data['Volume'].sort_values(ascending=True).head(20)
# Out:
# 29            0
# 114           1
# 18            5
# 161           6
# 47           23
# 90           25
# 66           78
# 2007     881300
# 245      984400
# 1001    1091200
# 126     1331700
# 879     1343400
# 426     1350600
# 376     1373000
# 497     1380400
# 405     1415000
# 411     1422600
# 415     1457100
# 1164    1458800
# 403     1504500
# Name: Volume, dtype: int64

# %%
# Which ones are larger than that number / true or false
data['Volume'] > 100000
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 2237    True
# 2238    True
# 2239    True
# 2240    True
# 2241    True
# Name: Volume, Length: 2235, dtype: bool

# %%
data=data[data['Volume'] > 100000]

# %%
data['Volume'].sort_values(ascending=True).head(20)
# Out:
# 2007     881300
# 245      984400
# 1001    1091200
# 126     1331700
# 879     1343400
# 426     1350600
# 376     1373000
# 497     1380400
# 405     1415000
# 411     1422600
# 415     1457100
# 1164    1458800
# 403     1504500
# 749     1513800
# 1167    1524100
# 151     1534300
# 417     1534700
# 152     1548100
# 1160    1563300
# 416     1566400
# Name: Volume, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2228 entries, 0 to 2241
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2228 non-null   object
#  1   Source     2228 non-null   object
#  2   Open       2228 non-null   float64
#  3   High       2228 non-null   float64
#  4   Low        2228 non-null   float64
#  5   Close      2228 non-null   float64
#  6   Adj Close  2228 non-null   float64
#  7   Volume     2228 non-null   int64
#  8   Stock      2228 non-null   object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 174.1+ KB

# %%
data.shape
# Out:
# (2228, 9)

# %%
##### Remove all columns that have a constant single value

# %%
data.head(5)
# Out:
#        Date Source        Open        High         Low       Close  \
# 0  1/3/2012  yahoo  175.889999  179.479996  175.550003  179.029999
# 1  1/4/2012  yahoo  179.210007  180.500000  176.070007  177.509995
# 2  1/5/2012  yahoo  175.940002  178.250000  174.050003  177.610001
# 3  1/6/2012  yahoo  178.070007  184.649994  177.500000  182.610001
# 4  1/9/2012  yahoo  182.759995  184.369995  177.000000  178.559998
#
#     Adj Close   Volume   Stock
# 0  179.029999  5110800  amazon
# 1  177.509995  4205200  amazon
# 2  177.610001  3809100  amazon
# 3  182.610001  7008400  amazon
# 4  178.559998  5056900  amazon

# %%
# See the last 20 of the 2000 data point set
data.tail(20)
# Out:
#             Date Source         Open         High          Low        Close  \
# 2222  10/30/2020  yahoo  3157.750000  3167.000000  3019.000000  3036.149902
# 2223   11/2/2020  yahoo  3061.739990  3079.709961  2950.120117  3004.479980
# 2224   11/3/2020  yahoo  3018.530029  3074.899902  2980.979980  3048.409912
# 2225   11/4/2020  yahoo  3159.989990  3244.850098  3139.729980  3241.159912
# 2226   11/5/2020  yahoo  3319.969971  3366.800049  3288.879883  3322.000000
# 2227   11/6/2020  yahoo  3304.639893  3322.000000  3232.000000  3311.370117
# 2228   11/9/2020  yahoo  3231.030029  3289.000000  3112.110107  3143.739990
# 2229  11/10/2020  yahoo  3095.020020  3114.000000  3019.479980  3035.020020
# 2230  11/11/2020  yahoo  3061.780029  3139.149902  3050.000000  3137.389893
# 2231  11/12/2020  yahoo  3159.949951  3175.879883  3086.050049  3110.280029
# 2232  11/13/2020  yahoo  3122.000000  3141.719971  3085.389893  3128.810059
# ...

# %%
data
# Out:
#             Date Source         Open         High          Low        Close  \
# 0       1/3/2012  yahoo   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012  yahoo   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012  yahoo   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012  yahoo   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012  yahoo   182.759995   184.369995   177.000000   178.559998
# ...          ...    ...          ...          ...          ...          ...
# 2237  11/20/2020  yahoo  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  yahoo  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  yahoo  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  yahoo  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  yahoo  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume   Stock
# ...

# %%
# Clean the data
# Loop through columns(numpy array) use .uniq and get the len of each column
# Find constant columns in the dataset
# Data C will return the column
#Add to list c
constant_columns = []
for c in data.columns:
    n = len(data[c].unique())
    if n==1:
        constant_columns.append(c)
        
print('Constant Columns: ',constant_columns)
# Out:
# Constant Columns:  ['Source', 'Stock']

# %%
data
# Out:
#             Date Source         Open         High          Low        Close  \
# 0       1/3/2012  yahoo   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012  yahoo   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012  yahoo   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012  yahoo   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012  yahoo   182.759995   184.369995   177.000000   178.559998
# ...          ...    ...          ...          ...          ...          ...
# 2237  11/20/2020  yahoo  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  yahoo  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  yahoo  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  yahoo  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  yahoo  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume   Stock
# ...

# %%
# Drop/Remove the constant columns from the data set
# Make axis one
# Save the change
data.drop(columns=constant_columns,axis=1,inplace=True)

# %%
data
# Out:
#             Date         Open         High          Low        Close  \
# 0       1/3/2012   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012   182.759995   184.369995   177.000000   178.559998
# ...          ...          ...          ...          ...          ...
# 2237  11/20/2020  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume
# 0      179.029999  5110800
# 1      177.509995  4205200
# 2      177.610001  3809100
# ...

# %%
data.shape
# Out:
# (2228, 7)

# %%
data.info
# Out:
# <bound method DataFrame.info of             Date         Open         High          Low        Close  \
# 0       1/3/2012   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012   182.759995   184.369995   177.000000   178.559998
# ...          ...          ...          ...          ...          ...
# 2237  11/20/2020  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume
# 0      179.029999  5110800
# 1      177.509995  4205200
# ...

# %%
# The data type is just an object
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2228 entries, 0 to 2241
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2228 non-null   object
#  1   Open       2228 non-null   float64
#  2   High       2228 non-null   float64
#  3   Low        2228 non-null   float64
#  4   Close      2228 non-null   float64
#  5   Adj Close  2228 non-null   float64
#  6   Volume     2228 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 139.2+ KB

# %%
# Adding Year, Month, Day Columns to the data 
# Call variable date object. Generating another data object
dateobject = pd.DatetimeIndex(data['Date'])

# %%
dateobject
# Out:
# DatetimeIndex(['2012-01-03', '2012-01-04', '2012-01-05', '2012-01-06',
#                '2012-01-09', '2012-01-10', '2012-01-11', '2012-01-12',
#                '2012-01-13', '2012-01-17',
#                ...
#                '2020-11-13', '2020-11-16', '2020-11-17', '2020-11-18',
#                '2020-11-19', '2020-11-20', '2020-11-23', '2020-11-24',
#                '2020-11-25', '2020-11-27'],
#               dtype='datetime64[ns]', name='Date', length=2228, freq=None)

# %%
# 

data['Year'] = dateobject.year
data['Month'] = dateobject.month
data['Day'] = dateobject.day
data
# Out:
#             Date         Open         High          Low        Close  \
# 0       1/3/2012   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012   182.759995   184.369995   177.000000   178.559998
# ...          ...          ...          ...          ...          ...
# 2237  11/20/2020  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume  Year  Month  Day
# 0      179.029999  5110800  2012      1    3
# 1      177.509995  4205200  2012      1    4
# ...

# %%
data[['Date','Year','Month','Day']]
# Out:
#             Date  Year  Month  Day
# 0       1/3/2012  2012      1    3
# 1       1/4/2012  2012      1    4
# 2       1/5/2012  2012      1    5
# 3       1/6/2012  2012      1    6
# 4       1/9/2012  2012      1    9
# ...          ...   ...    ...  ...
# 2237  11/20/2020  2020     11   20
# 2238  11/23/2020  2020     11   23
# 2239  11/24/2020  2020     11   24
# 2240  11/25/2020  2020     11   25
# 2241  11/27/2020  2020     11   27
#
# [2228 rows x 4 columns]

# %%
# Date still Objexct but the others are integers
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2228 entries, 0 to 2241
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2228 non-null   object
#  1   Open       2228 non-null   float64
#  2   High       2228 non-null   float64
#  3   Low        2228 non-null   float64
#  4   Close      2228 non-null   float64
#  5   Adj Close  2228 non-null   float64
#  6   Volume     2228 non-null   int64
#  7   Year       2228 non-null   int64
#  8   Month      2228 non-null   int64
#  9   Day        2228 non-null   int64
# dtypes: float64(5), int64(4), object(1)
# memory usage: 191.5+ KB

# %%
# Transform the values of Volume entries to represent thousands
data['Volume']=data['Volume']/1000
data.head()
# Out:
#        Date        Open        High         Low       Close   Adj Close  \
# 0  1/3/2012  175.889999  179.479996  175.550003  179.029999  179.029999
# 1  1/4/2012  179.210007  180.500000  176.070007  177.509995  177.509995
# 2  1/5/2012  175.940002  178.250000  174.050003  177.610001  177.610001
# 3  1/6/2012  178.070007  184.649994  177.500000  182.610001  182.610001
# 4  1/9/2012  182.759995  184.369995  177.000000  178.559998  178.559998
#
#    Volume  Year  Month  Day
# 0  5110.8  2012      1    3
# 1  4205.2  2012      1    4
# 2  3809.1  2012      1    5
# 3  7008.4  2012      1    6
# 4  5056.9  2012      1    9

# %%
# Use Visualization for Data Analysis
# For these two columns I want to group by the year and give me the totals
data[['Year','Volume']].groupby('Year').sum()
# Out:
#          Volume
# Year
# 2012   975492.4
# 2013   747905.7
# 2014  1029066.7
# 2015   957102.0
# 2016  1038756.3
# 2017   882705.4
# 2018  1417897.6
# 2019   974729.4
# 2020  1166035.7

# %%
# How to use the data and create a graph by it
data[['Year','Volume']].groupby('Year').sum().plot(figsize=(8,6), y='Volume',fontsize=12,title="Stock's Volume Over the Years")
plt.ylabel("Stock's Volume")
# Out:
# Text(0, 0.5, "Stock's Volume")

# %%
# Show the trend of the stock's volume over months
stock_months = data[['Month','Volume']].groupby('Month').sum()

# %%
stock_months
# Out:
#          Volume
# Month
# 1      884620.5
# 2      846030.2
# 3      839584.5
# 4      890804.0
# 5      693382.7
# 6      671267.7
# 7      792035.2
# 8      633655.4
# 9      650017.7
# 10     897270.2
# 11     743073.6
# 12     647949.5

# %%
stock_months.plot(figsize=(8,6), y='Volume',fontsize=12,title="Stock's Volume Over the Years")
plt.ylabel("Stock's Volume")
# Out:
# Text(0, 0.5, "Stock's Volume")

# %%
data[['Day','Volume']].groupby('Day').sum()
stock_months.plot(figsize=(8,6), y='Volume',fontsize=12,title="Stock's Volume Over the Days")
plt.ylabel("Stock's Volume")
# Out:
# Text(0, 0.5, "Stock's Volume")

# %%
data[['Day','Volume']].groupby('Day').sum()
stock_months.plot.bar(figsize=(8,6), y='Volume',fontsize=12,title="Stock's Volume Over the Days")
plt.ylabel("Stock's Volume")
# Out:
# Text(0, 0.5, "Stock's Volume")

# %%
# Show the closing per date
data[['Date','Adj Close']].plot(figsize=(10,8),x='Date',y='Adj Close',fontsize=12,title='Closing Price over the passed 8 yrs')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2228 entries, 0 to 2241
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2228 non-null   object
#  1   Open       2228 non-null   float64
#  2   High       2228 non-null   float64
#  3   Low        2228 non-null   float64
#  4   Close      2228 non-null   float64
#  5   Adj Close  2228 non-null   float64
#  6   Volume     2228 non-null   float64
#  7   Year       2228 non-null   int64
#  8   Month      2228 non-null   int64
#  9   Day        2228 non-null   int64
# dtypes: float64(6), int64(3), object(1)
# memory usage: 191.5+ KB

# %%
# Transform the date columns from object to Datatime object
# PD is change the object type
data['Date']=pd.to_datetime(data['Date'], format='%m/%d/%Y')
data
# Out:
#            Date         Open         High          Low        Close  \
# 0    2012-01-03   175.889999   179.479996   175.550003   179.029999
# 1    2012-01-04   179.210007   180.500000   176.070007   177.509995
# 2    2012-01-05   175.940002   178.250000   174.050003   177.610001
# 3    2012-01-06   178.070007   184.649994   177.500000   182.610001
# 4    2012-01-09   182.759995   184.369995   177.000000   178.559998
# ...         ...          ...          ...          ...          ...
# 2237 2020-11-20  3117.020020  3132.889893  3098.050049  3099.399902
# 2238 2020-11-23  3116.699951  3139.750000  3065.459961  3098.389893
# 2239 2020-11-24  3100.500000  3134.250000  3086.260010  3118.060059
# 2240 2020-11-25  3141.870117  3198.000000  3140.260010  3185.070068
# 2241 2020-11-27  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close  Volume  Year  Month  Day
# 0      179.029999  5110.8  2012      1    3
# 1      177.509995  4205.2  2012      1    4
# ...

# %%
# Now you see date is datatime
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2228 entries, 0 to 2241
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2228 non-null   datetime64[ns]
#  1   Open       2228 non-null   float64
#  2   High       2228 non-null   float64
#  3   Low        2228 non-null   float64
#  4   Close      2228 non-null   float64
#  5   Adj Close  2228 non-null   float64
#  6   Volume     2228 non-null   float64
#  7   Year       2228 non-null   int64
#  8   Month      2228 non-null   int64
#  9   Day        2228 non-null   int64
# dtypes: datetime64[ns](1), float64(6), int64(3)
# memory usage: 191.5 KB

# %%
# Show the closing per date
data[['Date','Adj Close']].plot(figsize=(10,8),x='Date',y='Adj Close',fontsize=12,title='Closing Price over the passed 8 yrs')

# %%
# Show the closing over months. Got rid of the x=month because that is the default
data[['Month','Adj Close']].groupby('Month').sum().plot(figsize=(10,8),y='Adj Close',fontsize=12,
                                                        title='Closing Price over months')
plt.ylabel('Sum of Adj Close Price')
# Out:
# Text(0, 0.5, 'Sum of Adj Close Price')

# %%
# Show the closing over months. Got rid of the x=month because that is the default
data[['Year','Adj Close']].groupby('Year').sum().plot(figsize=(10,8),y='Adj Close',fontsize=12,
                                                        title='Closing Price over years')
plt.ylabel('Sum of Adj Close Price')
# Out:
# Text(0, 0.5, 'Sum of Adj Close Price')

# %%
# Show the mean per month over the years
data[['Month','Adj Close']].groupby('Month').mean().plot(figsize=(10,8),y='Adj Close',fontsize=12,
                                                        title='Closing Price over years')
plt.ylabel('Sum of Adj Close Price')
# Out:
# Text(0, 0.5, 'Sum of Adj Close Price')

# %%
# Using Filters.
# Pl;ot the adj close prices that are smaller than the open prices and after 2015
data[data['Year']>2015]
# Out:
#            Date         Open         High          Low        Close  \
# 1006 2016-01-04   656.289978   657.719971   627.510010   636.989990
# 1007 2016-01-05   646.859985   646.909973   627.650024   633.789978
# 1008 2016-01-06   622.000000   639.789978   620.309998   632.650024
# 1009 2016-01-07   621.799988   630.000000   605.210022   607.940002
# 1010 2016-01-08   619.659973   624.140015   606.000000   607.049988
# ...         ...          ...          ...          ...          ...
# 2237 2020-11-20  3117.020020  3132.889893  3098.050049  3099.399902
# 2238 2020-11-23  3116.699951  3139.750000  3065.459961  3098.389893
# 2239 2020-11-24  3100.500000  3134.250000  3086.260010  3118.060059
# 2240 2020-11-25  3141.870117  3198.000000  3140.260010  3185.070068
# 2241 2020-11-27  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close  Volume  Year  Month  Day
# 1006   636.989990  9314.5  2016      1    4
# 1007   633.789978  5822.6  2016      1    5
# ...

# %%
# Smaller or = to 2015
data[data['Year']>=2015]
# Out:
#            Date         Open         High          Low        Close  \
# 754  2015-01-02   312.579987   314.750000   306.959991   308.519989
# 755  2015-01-05   307.010010   308.380005   300.850006   302.190002
# 756  2015-01-06   302.239990   303.000000   292.380005   295.290009
# 757  2015-01-07   297.500000   301.279999   295.329987   298.420013
# 758  2015-01-08   300.320007   303.140015   296.109985   300.459991
# ...         ...          ...          ...          ...          ...
# 2237 2020-11-20  3117.020020  3132.889893  3098.050049  3099.399902
# 2238 2020-11-23  3116.699951  3139.750000  3065.459961  3098.389893
# 2239 2020-11-24  3100.500000  3134.250000  3086.260010  3118.060059
# 2240 2020-11-25  3141.870117  3198.000000  3140.260010  3185.070068
# 2241 2020-11-27  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close  Volume  Year  Month  Day
# 754    308.519989  2783.2  2015      1    2
# 755    302.190002  2774.2  2015      1    5
# ...

# %%
# records greater than or equal to after year 2015. Open at price and sell at equal to or lower price
filter1=data[data['Year']>=2015]
len(filter1)
# Out:
# 1488

# %%
# See where close is smaller than open
filter2=data[data['Adj Close'] < data['Open']]
filter2
# Out:
#            Date         Open         High          Low        Close  \
# 1    2012-01-04   179.210007   180.500000   176.070007   177.509995
# 4    2012-01-09   182.759995   184.369995   177.000000   178.559998
# 5    2012-01-10   181.100006   182.399994   177.100006   179.339996
# 6    2012-01-11   179.639999   180.770004   178.190002   178.899994
# 7    2012-01-12   179.419998   179.490005   175.750000   175.929993
# ...         ...          ...          ...          ...          ...
# 2234 2020-11-17  3183.540039  3189.250000  3135.260010  3135.659912
# 2235 2020-11-18  3134.000000  3140.000000  3105.100098  3105.459961
# 2237 2020-11-20  3117.020020  3132.889893  3098.050049  3099.399902
# 2238 2020-11-23  3116.699951  3139.750000  3065.459961  3098.389893
# 2241 2020-11-27  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close  Volume  Year  Month  Day
# 1      177.509995  4205.2  2012      1    4
# 4      178.559998  5056.9  2012      1    9
# ...

# %%
len(filter2)
# Out:
# 1105

# %%
# Plot this above info. Show if it satisfies the position
filter1=data['Year']>=2015
filter1
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2237     True
# 2238     True
# 2239     True
# 2240     True
# 2241     True
# Name: Year, Length: 2228, dtype: bool

# %%
# All years lower than open
filter2=data['Adj Close'] < data['Open']
filter2
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 2237     True
# 2238     True
# 2239    False
# 2240    False
# 2241     True
# Length: 2228, dtype: bool

# %%
# Create new data set
    # Another way add whole condition: result=data[data['Year']>2015 & data[data['Adj Close'] < data['Open']]]
result=data[filter1 & filter2]

# %%
result['Open'].sum()
# Out:
# 1008166.540066

# %%
result['Adj Close'].sum()
# Out:
# 996313.698968

# %%
result['Open'].sum() - result['Adj Close'].mean()
# Out:
# 1006823.7992318113

# %%
result[['Year','Adj Close']].groupby('Year').count()
# Out:
#       Adj Close
# Year
# 2015        126
# 2016        127
# 2017        128
# 2018        124
# 2019        125
# 2020        112

# %%
result[['Year','Adj Close']].groupby('Year').count().plot.bar(figsize=(8,6),
                                                              fontsize=12,title="Years")
plt.ylabel('Number of Stocks')
# Out:
# Text(0, 0.5, 'Number of Stocks')

# %%
result[['Month','Adj Close']].groupby('Month').count().plot.bar(figsize=(8,6),
                                                              fontsize=12,title="Months")
plt.ylabel('Number of Stocks')
# Out:
# Text(0, 0.5, 'Number of Stocks')

# %%
# Compare the open and adj close values / prices over years
data
# Out:
#            Date         Open         High          Low        Close  \
# 0    2012-01-03   175.889999   179.479996   175.550003   179.029999
# 1    2012-01-04   179.210007   180.500000   176.070007   177.509995
# 2    2012-01-05   175.940002   178.250000   174.050003   177.610001
# 3    2012-01-06   178.070007   184.649994   177.500000   182.610001
# 4    2012-01-09   182.759995   184.369995   177.000000   178.559998
# ...         ...          ...          ...          ...          ...
# 2237 2020-11-20  3117.020020  3132.889893  3098.050049  3099.399902
# 2238 2020-11-23  3116.699951  3139.750000  3065.459961  3098.389893
# 2239 2020-11-24  3100.500000  3134.250000  3086.260010  3118.060059
# 2240 2020-11-25  3141.870117  3198.000000  3140.260010  3185.070068
# 2241 2020-11-27  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close  Volume  Year  Month  Day
# 0      179.029999  5110.8  2012      1    3
# 1      177.509995  4205.2  2012      1    4
# ...

# %%
data[['Year','Open','Adj Close']].groupby('Year').sum().plot(figsize=(10,8), y=['Open','Adj Close'],fontsize=12,legend=True,
                                                            title='Compare the Open and Adj Close Stocks stock/year')
plt.ylabel("Stock's Prices")
# Out:
# Text(0, 0.5, "Stock's Prices")

# %%
data[['Year','Open','Adj Close']].groupby('Year').sum()
# Out:
#                Open      Adj Close
# Year
# 2012   52225.659955   52285.690045
# 2013   75064.529882   75103.960123
# 2014   83865.209893   83802.860235
# 2015  120487.490167  120490.850372
# 2016  176338.659969  176279.829985
# 2017  243037.180357  243009.919923
# 2018  412662.250000  412073.270138
# 2019  450764.039797  450875.679928
# 2020  604687.140872  604737.799191

# %%
data[['Month','Open','Adj Close']].groupby('Month').sum().plot(figsize=(10,8), y=['Open','Adj Close'],fontsize=12,legend=True,
                                                            title='Compare the Open and Adj Close Stocks stock/year')
plt.ylabel("Stock's Prices")
# Out:
# Text(0, 0.5, "Stock's Prices")

# %%
data[['Day','Open','Adj Close']].groupby('Day').sum().plot(figsize=(10,8), y=['Open','Adj Close'],fontsize=12,legend=True,
                                                            title='Compare the Open and Adj Close Stocks stock/year')
plt.ylabel("Stock's Prices")
# Out:
# Text(0, 0.5, "Stock's Prices")

# %%
# Compare the average high and low values / prices over months
data[['Month','High','Adj Close']].groupby('Month').sum().plot(figsize=(10,8), y=['High','Adj Close'],fontsize=12,legend=True,
                                                            title='Compare the High and Low Stocks stock/year')
plt.ylabel("Stock's Prices")
# Out:
# Text(0, 0.5, "Stock's Prices")

# %%
# Compare the average high and low values / prices over years
data[['Year','High','Adj Close']].groupby('Year').sum().plot(figsize=(10,8), y=['High','Adj Close'],fontsize=12,legend=True,
                                                            title='Compare the High and Low Stocks stock/year')
plt.ylabel("Stock's Prices")
# Out:
# Text(0, 0.5, "Stock's Prices")

# %%
# Compare the average high and low values / prices over years
data[['Year','High','Adj Close']].groupby('Year').mean().plot(figsize=(10,8), y=['High','Adj Close'],fontsize=12,legend=True,
                                                            title='Compare the High and Low Stocks stock/year')
plt.ylabel("Stock's Prices")
# Out:
# Text(0, 0.5, "Stock's Prices")

# %%
# Compare the average high and low values / prices over years
data[['Month','High','Adj Close']].groupby('Month').mean().plot(figsize=(10,8), y=['High','Adj Close'],fontsize=12,legend=True,
                                                            title='Compare the High and Low Stocks stock/year')
plt.ylabel("Stock's Prices")
# Out:
# Text(0, 0.5, "Stock's Prices")

# %%
# Compare the average high and low values / prices over years
data[['Day','High','Adj Close']].groupby('Day').sum().plot(figsize=(10,8), y=['High','Adj Close'],fontsize=12,legend=True,
                                                            title='Compare the High, Low, Adj Close Stocks stock/year')
plt.ylabel("Stock's Prices")
# Out:
# Text(0, 0.5, "Stock's Prices")

# %%
# Compare the average High, Low, and Adj Values / prices over months
data[['Month','High','Low','Adj Close']].groupby('Month').sum().plot(figsize=(10,8), y=['High','Low','Adj Close'],fontsize=12,legend=True,
                                                            title='Compare the High, Low, Adj Close Stocks stock/year')
plt.ylabel("High and Low Stock Prices")
# Out:
# Text(0, 0.5, 'High and Low Stock Prices')

# %%
data[['Month','High','Low','Adj Close']]
# Out:
#       Month         High          Low    Adj Close
# 0         1   179.479996   175.550003   179.029999
# 1         1   180.500000   176.070007   177.509995
# 2         1   178.250000   174.050003   177.610001
# 3         1   184.649994   177.500000   182.610001
# 4         1   184.369995   177.000000   178.559998
# ...     ...          ...          ...          ...
# 2237     11  3132.889893  3098.050049  3099.399902
# 2238     11  3139.750000  3065.459961  3098.389893
# 2239     11  3134.250000  3086.260010  3118.060059
# 2240     11  3198.000000  3140.260010  3185.070068
# 2241     11  3216.189941  3190.050049  3195.340088
#
# [2228 rows x 4 columns]

# %%
data[['Month','High','Low','Adj Close']].groupby('Month').mean().plot(figsize=(10,8), y=['High','Low','Adj Close'],fontsize=12,legend=True,
                                                            title='Compare the High, Low, Adj Close Stocks stock/year')
plt.ylabel("High and Low Stock Prices")
# Out:
# Text(0, 0.5, 'High and Low Stock Prices')

# %%
# See what if being plotted looking at high, low, adj numbers are 'sum'
data[['Month','High','Low','Adj Close']].groupby('Month').sum()
# Out:
#                 High            Low      Adj Close
# Month
# 1      153815.229659  150459.250262  152373.629950
# 2      147815.070893  144299.100271  146053.359938
# 3      168687.200211  164302.230122  166751.649797
# 4      173063.989368  169037.909943  171224.489851
# 5      186470.270370  183195.429752  184985.700313
# 6      195758.049326  191980.120292  193977.700201
# 7      214561.970152  209402.930095  212203.470119
# 8      222609.169706  218586.620064  220699.389863
# 9      206952.850025  202123.789281  204492.010192
# 10     226877.489150  221142.320153  223882.629720
# 11     202792.599750  198282.249806  200683.650231
# 12     143058.720151  139853.389868  141332.179765

# %%
# See the average betwen the two now
data[['Month','High','Low','Adj Close']].groupby('Month').mean()
# Out:
#               High          Low    Adj Close
# Month
# 1       845.138624   826.699177   837.217747
# 2       869.500417   848.818237   859.137411
# 3       883.179059   860.221100   873.045287
# 4       935.481024   913.718432   925.537783
# 5       981.422476   964.186472   973.608949
# 6      1030.305523  1010.421686  1020.935264
# 7      1117.510261  1090.640261  1105.226407
# 8      1124.288736  1103.972829  1114.643383
# 9      1137.103572  1110.570271  1123.582474
# 10     1134.387446  1105.711601  1119.413149
# 11     1114.245054  1089.462911  1102.657419
# 12      861.799519   842.490300   851.398673

# %%
# How many values you have per month in each column
data[['Month','High','Low','Adj Close']].groupby('Month').count()
# Out:
#        High  Low  Adj Close
# Month
# 1       182  182        182
# 2       170  170        170
# 3       191  191        191
# 4       185  185        185
# 5       190  190        190
# 6       190  190        190
# 7       192  192        192
# 8       198  198        198
# 9       182  182        182
# 10      200  200        200
# 11      182  182        182
# 12      166  166        166

# %%
data[['Year','High','Low','Adj Close']].groupby('Year').mean()
# Out:
#              High          Low    Adj Close
# Year
# 2012   223.936483   218.845169   221.549534
# 2013   300.925991   294.656506   298.031588
# 2014   336.317540   328.545436   332.551033
# 2015   483.196231   472.882143   478.138295
# 2016   705.804959   692.646230   699.523135
# 2017   974.518766   960.734065   968.167012
# 2018  1662.839839  1619.840519  1641.726176
# 2019  1802.590081  1773.117302  1789.189206
# 2020  2665.957474  2590.035043  2629.294779

# %%
data[['Year','High','Low','Adj Close']].groupby('Year').mean().plot(figsize=(10,8), y=['High','Low','Adj Close'],fontsize=12,legend=True,
                                                            title='Compare the High, Low, Adj Close Stocks stock/year')
plt.ylabel("High and Low Stock Prices")
# Out:
# Text(0, 0.5, 'High and Low Stock Prices')

# %%
data[['Date','High','Low','Adj Close']].groupby('Date').mean().plot(figsize=(10,8), y=['High','Low','Adj Close'],fontsize=12,legend=True,
                                                            title='Compare the High, Low, Adj Close Stocks stock/year')
plt.ylabel("High and Low Stock Prices")
# Out:
# Text(0, 0.5, 'High and Low Stock Prices')

# %%
# The Same as above!!!!
data[['Date','High','Low','Adj Close']].plot(figsize=(10,8), y=['High','Low','Adj Close'],fontsize=12,legend=True,
                                                            title='Compare the High, Low, Adj Close Stocks stock/year')
plt.ylabel("High and Low Stock Prices")
# Out:
# Text(0, 0.5, 'High and Low Stock Prices')

# %%
data.head(20)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2012-01-03  175.889999  179.479996  175.550003  179.029999  179.029999
# 1  2012-01-04  179.210007  180.500000  176.070007  177.509995  177.509995
# 2  2012-01-05  175.940002  178.250000  174.050003  177.610001  177.610001
# 3  2012-01-06  178.070007  184.649994  177.500000  182.610001  182.610001
# 4  2012-01-09  182.759995  184.369995  177.000000  178.559998  178.559998
# 5  2012-01-10  181.100006  182.399994  177.100006  179.339996  179.339996
# 6  2012-01-11  179.639999  180.770004  178.190002  178.899994  178.899994
# 7  2012-01-12  179.419998  179.490005  175.750000  175.929993  175.929993
# 8  2012-01-13  175.809998  178.800003  173.500000  178.419998  178.419998
# 9  2012-01-17  180.149994  183.300003  178.509995  181.660004  181.660004
# 10 2012-01-18  181.940002  190.250000  181.119995  189.440002  189.440002
# 11 2012-01-19  190.880005  195.940002  190.360001  194.449997  194.449997
# ...

# %%
# Query the data to answer some questions
# Find the months that have the highest and lowst number of volume
# r is sub data set
r=data[['Month','Volume']].groupby('Month').sum()
r
# Out:
#          Volume
# Month
# 1      884620.5
# 2      846030.2
# 3      839584.5
# 4      890804.0
# 5      693382.7
# 6      671267.7
# 7      792035.2
# 8      633655.4
# 9      650017.7
# 10     897270.2
# 11     743073.6
# 12     647949.5

# %%
r=data[['Month','Volume']].groupby('Month').sum()

# %%
r.min()
# Out:
# Volume    633655.4
# dtype: float64

# %%
r.max()
# Out:
# Volume    897270.2
# dtype: float64

# %%
r.idxmin()
# Out:
# Volume    8
# dtype: int64

# %%
r.idxmax()
# Out:
# Volume    10
# dtype: int64

# %%
print(r.idxmax())
# Out:
# Volume    10
# dtype: int64

# %%
print(r.idxmax()[0])
print(r.idxmin()[0])
# Out:
# 10
# 8

# %%
print('The month with the lowest volume', r.idxmin()[0],'Volume',r.min()[0]*1000)
print('The month with the highest volume', r.idxmax()[0],'Volume',r.max()[0]*1000)
# Out:
# The month with the lowest volume 8 Volume 633655399.9999995
# The month with the highest volume 10 Volume 897270199.9999995

# %%
# Find the dates that have the highest and lowest number of volumes
# What are the dates? Dates are unique. No need to group at all. Unlike individual day, month, year
data
# Out:
#            Date         Open         High          Low        Close  \
# 0    2012-01-03   175.889999   179.479996   175.550003   179.029999
# 1    2012-01-04   179.210007   180.500000   176.070007   177.509995
# 2    2012-01-05   175.940002   178.250000   174.050003   177.610001
# 3    2012-01-06   178.070007   184.649994   177.500000   182.610001
# 4    2012-01-09   182.759995   184.369995   177.000000   178.559998
# ...         ...          ...          ...          ...          ...
# 2237 2020-11-20  3117.020020  3132.889893  3098.050049  3099.399902
# 2238 2020-11-23  3116.699951  3139.750000  3065.459961  3098.389893
# 2239 2020-11-24  3100.500000  3134.250000  3086.260010  3118.060059
# 2240 2020-11-25  3141.870117  3198.000000  3140.260010  3185.070068
# 2241 2020-11-27  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close  Volume  Year  Month  Day
# 0      179.029999  5110.8  2012      1    3
# 1      177.509995  4205.2  2012      1    4
# ...

# %%
# Makes r the column 'volume'
r=data['Volume']
r
# Out:
# 0       5110.8
# 1       4205.2
# 2       3809.1
# 3       7008.4
# 4       5056.9
#          ...
# 2237    3374.4
# 2238    4708.9
# 2239    3602.1
# 2240    3790.4
# 2241    2392.9
# Name: Volume, Length: 2228, dtype: float64

# %%
s=r.idxmin()
l=r.idxmax()
print('The row index with the lowest volume is ',s)
print('The row index with the highest volume is ',l)
# Out:
# The row index with the lowest volume is  2007
# The row index with the highest volume is  773

# %%
data
# Out:
#            Date         Open         High          Low        Close  \
# 0    2012-01-03   175.889999   179.479996   175.550003   179.029999
# 1    2012-01-04   179.210007   180.500000   176.070007   177.509995
# 2    2012-01-05   175.940002   178.250000   174.050003   177.610001
# 3    2012-01-06   178.070007   184.649994   177.500000   182.610001
# 4    2012-01-09   182.759995   184.369995   177.000000   178.559998
# ...         ...          ...          ...          ...          ...
# 2237 2020-11-20  3117.020020  3132.889893  3098.050049  3099.399902
# 2238 2020-11-23  3116.699951  3139.750000  3065.459961  3098.389893
# 2239 2020-11-24  3100.500000  3134.250000  3086.260010  3118.060059
# 2240 2020-11-25  3141.870117  3198.000000  3140.260010  3185.070068
# 2241 2020-11-27  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close  Volume  Year  Month  Day
# 0      179.029999  5110.8  2012      1    3
# 1      177.509995  4205.2  2012      1    4
# ...

# %%
# Gives you the row by index
print('The date with the lowest volume',data.iloc[s]['Date'],' Volume ', data.iloc[s]['Volume'])
print('The date with the largest volume',data.iloc[l]['Date'],' Volume ', data.iloc[l]['Volume'])
# Out:
# The date with the lowest volume 2020-01-15 00:00:00  Volume  2896.6
# The date with the largest volume 2015-02-20 00:00:00  Volume  3258.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2228 entries, 0 to 2241
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2228 non-null   datetime64[ns]
#  1   Open       2228 non-null   float64
#  2   High       2228 non-null   float64
#  3   Low        2228 non-null   float64
#  4   Close      2228 non-null   float64
#  5   Adj Close  2228 non-null   float64
#  6   Volume     2228 non-null   float64
#  7   Year       2228 non-null   int64
#  8   Month      2228 non-null   int64
#  9   Day        2228 non-null   int64
# dtypes: datetime64[ns](1), float64(6), int64(3)
# memory usage: 271.5 KB

# %%
# Just want date not time change by adding a .date
print('The date with the lowest volume',data.iloc[s]['Date'].date(),' Volume ', data.iloc[s]['Volume'])
print('The date with the largest volume',data.iloc[l]['Date'].date(),' Volume ', data.iloc[l]['Volume'])
# Out:
# The date with the lowest volume 2020-01-15  Volume  2896.6
# The date with the largest volume 2015-02-20  Volume  3258.0

# %%
# Find the month and day that has the lowest closing average price!
data[['Month','Day','Adj Close']]
# Out:
#       Month  Day    Adj Close
# 0         1    3   179.029999
# 1         1    4   177.509995
# 2         1    5   177.610001
# 3         1    6   182.610001
# 4         1    9   178.559998
# ...     ...  ...          ...
# 2237     11   20  3099.399902
# 2238     11   23  3098.389893
# 2239     11   24  3118.060059
# 2240     11   25  3185.070068
# 2241     11   27  3195.340088
#
# [2228 rows x 3 columns]

# %%
# Store result into R
r=data[['Month','Day','Adj Close']].groupby(['Month','Day']).mean()
r
# Out:
#             Adj Close
# Month Day
# 1     2    931.658335
#       3    881.009992
#       4    769.301659
#       5    624.636002
#       6    700.508339
# ...               ...
# 12    27   988.581681
#       28   871.326001
#       29   735.157494
#       30   797.900000
#       31   830.951660
#
# [363 rows x 1 columns]

# %%
# The 2 is the month and the day is th 29. Lowest price on 2/29
r.idxmin()
# Out:
# Adj Close    (2, 29)
# dtype: object

# %%
r.idxmax()
# Out:
# Adj Close    (9, 1)
# dtype: object

# %%
# Returns the value
r.min()
# Out:
# Adj Close    366.105011
# dtype: float64

# %%
r.min()
# Out:
# Adj Close    366.105011
# dtype: float64

# %%
print('The month and day with the lowst closing price is ',r.idxmin()[0], 'The average Adj Closing Price is ',r.min()[0])
# Out:
# The month and day with the lowst closing price is  (2, 29) The average Adj Closing Price is  366.105011

# %%
# Show the closing, open, year, month, day of the highest volume
data
# Out:
#            Date         Open         High          Low        Close  \
# 0    2012-01-03   175.889999   179.479996   175.550003   179.029999
# 1    2012-01-04   179.210007   180.500000   176.070007   177.509995
# 2    2012-01-05   175.940002   178.250000   174.050003   177.610001
# 3    2012-01-06   178.070007   184.649994   177.500000   182.610001
# 4    2012-01-09   182.759995   184.369995   177.000000   178.559998
# ...         ...          ...          ...          ...          ...
# 2237 2020-11-20  3117.020020  3132.889893  3098.050049  3099.399902
# 2238 2020-11-23  3116.699951  3139.750000  3065.459961  3098.389893
# 2239 2020-11-24  3100.500000  3134.250000  3086.260010  3118.060059
# 2240 2020-11-25  3141.870117  3198.000000  3140.260010  3185.070068
# 2241 2020-11-27  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close  Volume  Year  Month  Day
# 0      179.029999  5110.8  2012      1    3
# 1      177.509995  4205.2  2012      1    4
# ...

# %%
r = data.loc[data['Volume'].idxmax()]
r
# Out:
# Date         2015-01-30 00:00:00
# Open                      346.32
# High                       359.5
# Low                       340.74
# Close                     354.53
# Adj Close                 354.53
# Volume                   23856.1
# Year                        2015
# Month                          1
# Day                           30
# Name: 773, dtype: object

# %%
# What is R? It is a Panda Series
type(r)
# Out:
# pandas.core.series.Series

# %%
# You can see all infor the for the max stock
r['Date']
# Out:
# Timestamp('2015-01-30 00:00:00')

# %%
r['Open']
# Out:
# 346.320007

# %%
print(r)
# Out:
# Date         2015-01-30 00:00:00
# Open                      346.32
# High                       359.5
# Low                       340.74
# Close                     354.53
# Adj Close                 354.53
# Volume                   23856.1
# Year                        2015
# Month                          1
# Day                           30
# Name: 773, dtype: object

# %%
print('Closing: ', r['Close'], 'Open: ', r['Open'],'Year: ',r['Year'],'Volume',r['Volume'])
# Out:
# Closing:  354.52999900000003 Open:  346.320007 Year:  2015 Volume 23856.1
